# %% [markdown]
# # Imports

# %%
import tensorflow as tf
# from tensorflow.python.framework.ops import disable_eager_execution 
# disable_eager_execution()
# from tensorflow.python.framework.ops import enable_eager_execution
# enable_eager_execution()
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Import common tensorflow layers and activations
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Layer
from tensorflow.keras.layers import Lambda, Multiply, Add, Rescaling
from tensorflow.keras.activations import relu, sigmoid, softmax
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras import Input

# from local_tabnet import TabNet as LocalTabNet
from tabnet import TabNet as TFTabNet

# %% [markdown]
# # Tabnet experiment Hyperparams

# %%
BATCH_SIZE = 16384
LAMBDA = 0.0001
N_A = 64
N_D = 64
VIRTUAL_BATCH_SIZE = 512
BATCH_MOMENTUM = 0.7
N_STEPS = 5
GAMMA = 1.5
LEARNING_RATE = tf.keras.optimizers.schedules.ExponentialDecay(
    0.02,
    decay_steps=500,
    decay_rate=0.95
    )
OPTIMIZER = tf.keras.optimizers.Adam(LEARNING_RATE)

# %% [markdown]
# # Data Defn

# %%
# Load telematics data
training = pd.read_csv("./poker_hand/poker-hand-training-true.data")
data_test = pd.read_csv("./poker_hand/poker-hand-testing.data")

training.columns = [
    'S1', 'C1', 'S2', 'C2', 'S3', 'C3', 'S4', 'C4', 'S5', 'C5', 'Hand'
]

data_test.columns = training.columns

response = 'Hand'
covariates = [c for c in training.columns if c != response]

training[covariates] = training[covariates].astype('float')
data_test[covariates] = data_test[covariates].astype('float')

# Split data into train and test
data_train, data_val = train_test_split(training, test_size=0.3, random_state=42)

# Split into X and y
X_train = data_train.drop(response, axis=1, errors='ignore')
y_train = data_train[response]
X_val = data_val.drop(response, axis=1, errors='ignore')
y_val = data_val[response]
X_test = data_test.drop(response, axis=1, errors='ignore')
y_test = data_test[response]

# Make tensorflow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train[..., np.newaxis]))
train_dataset = train_dataset.shuffle(buffer_size=4048).batch(BATCH_SIZE, drop_remainder=True)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val[..., np.newaxis]))
val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test[..., np.newaxis]))
test_dataset = test_dataset.batch(BATCH_SIZE, drop_remainder=True)
# Out:
# /tmp/ipykernel_66815/569520097.py:31: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train[..., np.newaxis]))
# /tmp/ipykernel_66815/569520097.py:33: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val[..., np.newaxis]))
# /tmp/ipykernel_66815/569520097.py:35: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test[..., np.newaxis]))

# %% [markdown]
# # Model creation and training

# %%
# import tensorflow as tf
# import tabnet
# from importlib import reload
# reload(tabnet)

# from tabnet import TabNet

# online_implementation = TabNet(
#     feature_columns=None,
#     output_dim=64,
#     feature_dim=128,
#     num_features=X_train.shape[1],
#     num_decision_steps=5,
#     relaxation_factor=1.5,
#     sparsity_coefficient=0.0001,
#     virtual_batch_size=512,
#     norm_type="batch",
#     batch_momentum=0.7,
# )

# online_implementation = Sequential([
#     online_implementation,
#     Dense(1, activation="sigmoid")
# ])


# online_implementation.compile(
#     optimizer=tf.keras.optimizers.Adam(
#         learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(
#             initial_learning_rate=0.02,
#             decay_steps=500,
#             decay_rate=0.95
#         ),
#     ),
#     loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
#     metrics=[
#         tf.keras.metrics.AUC(from_logits=False, name="auc"),
#         tf.keras.metrics.BinaryAccuracy(name="binary_accuracy"),
#         tf.keras.metrics.Precision(name="precision", thresholds=0.5),
#         tf.keras.metrics.Recall(name="recall", thresholds=0.5)
#     ]
# )

# %%
# sample = next(iter(train_dataset))
# x = np.arange(len(sample[0].numpy()))
# online_implementation(sample[0])

# %%
class CategoryEmebddingShimLayer(Layer):
    def __init__(
            self,
            cat_idxs=None,
            num_cats=None,
            embed_dim=1, # TODO: make arbitrary sized embedding dim
            **kwargs):
        super(CategoryEmebddingShimLayer, self).__init__(**kwargs)
        self.cat_idxs = cat_idxs
        self.num_cats = num_cats
        if isinstance(embed_dim, list):
            assert len(embed_dim) == len(cat_idxs), f"embed_dim {len(embed_dim)} must be same length as cat_idxs {len(cat_idxs)}"
        self.embed_dim = 1
        self.embeddings = []
        assert len(cat_idxs) == len(num_cats), f"cat_idxs {len(cat_idxs)} must be same length as num_cats {len(num_cats)}"
    
    def build(self, input_shape):
        for i, nrow in enumerate(self.num_cats):
            if isinstance(self.embed_dim, list):
                ncol = self.embed_dim[i]
            else:
                ncol = self.embed_dim

            embedding = self.add_weight(
                shape=(nrow, ncol),
                initializer="uniform",
                trainable=True,
                name=f"embedding_{i}"
            )
            self.embeddings.append(embedding)
        super(CategoryEmebddingShimLayer, self).build(input_shape)

    def call(self, inputs):
        x = inputs # (B,D) - float/int mix
        for i, cat_idx in enumerate(self.cat_idxs):
            x_cat = tf.gather(x, cat_idx, axis=1) # (B,1) - int
            x_cat = tf.nn.embedding_lookup(self.embeddings[i], tf.cast(x_cat-1, tf.int32)) # (B,E) - float
            x = tf.concat([x[:, :cat_idx], x_cat, x[:, cat_idx+1:]], axis=1)
        return x

    def compute_output_shape(self, input_shape):
        # Calculate new shape according to cat idxs and num cats in each
        new_shape = input_shape[1]
        for i, _ in enumerate(self.cat_idxs):
            new_shape -= 1
            if isinstance(self.embed_dim, list):
                new_shape += self.embed_dim[i]
            else:
                new_shape += self.embed_dim
        return (input_shape[0], new_shape)

# %%
# Test the layer
cat_idxs = [0, 1, 2, 3, 4]
num_cats = [4, 13, 4, 13, 4]

layer = CategoryEmebddingShimLayer(cat_idxs, num_cats, embed_dim=1)
layer.build((None, 10))
dummy_shape = (7, 10)
dummy_in = tf.ones(dummy_shape, dtype=tf.float32)
dummy_out = layer(dummy_in)
assert dummy_out.shape == dummy_shape
expected_out = []
for i, idx in enumerate(cat_idxs):
    expected_out.append(layer.embeddings[i][0])

dummy_out,  tf.concat(expected_out, axis=-1)
# Out:
# (<tf.Tensor: shape=(7, 10), dtype=float32, numpy=
#  array([[ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ],
#         [ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407,
#           1.        ,  1.        ,  1.        ,  1.        ,  1.        ]],
#        dtype=float32)>,
#  <tf.Tensor: shape=(5,), dtype=float32, numpy=
#  array([ 0.11982822, -0.03665085,  0.01150975,  0.07373473, -0.06221407],
#        dtype=float32)>)

# %%
real_num_cats = [training[col].nunique() for col in training.columns if col != response]

local_implementation = LocalTabNet(
    dim_features=X_train.shape[1],
    dim_attention=16,
    dim_output=10,
    output_activation='softmax',
    sparsity=1e-7,
    num_steps=4,
    gamma=1.5,
    preprocess_layers=CategoryEmebddingShimLayer(np.arange(X_train.shape[1]), real_num_cats, embed_dim=1),
    )

local_implementation.compile( 
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=[
        tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        ]
)
local_implementation.build(X_train[:1].shape)

# %%
local_implementation.summary()
# Out:
# Model: "tab_net_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# category_emebdding_shim_laye multiple                  85
# _________________________________________________________________
# shared_feature_layer (Shared multiple                  5888
# _________________________________________________________________
# feat_0 (FeatureTransformer)  multiple                  12480
# _________________________________________________________________
# feat_1 (FeatureTransformer)  multiple                  12480
# _________________________________________________________________
# feat_2 (FeatureTransformer)  multiple                  12480
# _________________________________________________________________
# feat_3 (FeatureTransformer)  multiple                  12480
# _________________________________________________________________
# feat_4 (FeatureTransformer)  multiple                  12480
# _________________________________________________________________
# attn_1 (AttentiveTransformer multiple                  210
# _________________________________________________________________
# attn_2 (AttentiveTransformer multiple                  210
# _________________________________________________________________
# attn_3 (AttentiveTransformer multiple                  210
# _________________________________________________________________
# attn_4 (AttentiveTransformer multiple                  210
# _________________________________________________________________
# norm_in (BatchNormalization) multiple                  40
# _________________________________________________________________
# output (Dense)               multiple                  170
# =================================================================
# Total params: 39,983
# Trainable params: 39,115
# Non-trainable params: 868
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True)
lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(patience=3, factor=0.5, min_lr=1e-5)
history = local_implementation.fit(train_dataset, epochs=1000, validation_data=val_dataset, callbacks=[early_stopping, lr_on_plateau])
# Out:
# Epoch 1/1000
# 17/17 [==============================] - 6s 44ms/step - loss: 1.0045 - accuracy: 0.4849
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 2/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 1.0177 - accuracy: 0.4775
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 3/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 1.0101 - accuracy: 0.4797
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 4/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 1.0031 - accuracy: 0.4802
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 5/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9997 - accuracy: 0.4876
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 6/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9968 - accuracy: 0.4909
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 7/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9951 - accuracy: 0.4917
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 8/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9972 - accuracy: 0.4880
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 9/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9941 - accuracy: 0.4940
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 10/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9943 - accuracy: 0.4960
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 11/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9936 - accuracy: 0.4949
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 12/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9930 - accuracy: 0.4922
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 13/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9918 - accuracy: 0.4955
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 14/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9928 - accuracy: 0.4900
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 15/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9920 - accuracy: 0.5002
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 16/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9923 - accuracy: 0.4910
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 17/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9923 - accuracy: 0.4955
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 18/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9908 - accuracy: 0.4955
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 19/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9903 - accuracy: 0.4976
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 20/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9895 - accuracy: 0.4961
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 21/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9898 - accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 22/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9866 - accuracy: 0.4993
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 23/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9886 - accuracy: 0.4996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 24/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9887 - accuracy: 0.4957
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 25/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9880 - accuracy: 0.4991
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 26/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.9864 - accuracy: 0.4986
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 27/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9887 - accuracy: 0.4977
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 28/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9918 - accuracy: 0.4949
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 29/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9904 - accuracy: 0.4955
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 30/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9921 - accuracy: 0.4937
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 31/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9931 - accuracy: 0.4982
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 32/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9913 - accuracy: 0.4957
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 33/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9910 - accuracy: 0.4975
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 34/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9881 - accuracy: 0.5014
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 35/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9889 - accuracy: 0.4985
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 36/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9890 - accuracy: 0.4992
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 37/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9889 - accuracy: 0.4961
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 38/1000
# 17/17 [==============================] - 1s 59ms/step - loss: 0.9884 - accuracy: 0.5009
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 39/1000
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9865 - accuracy: 0.4997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 40/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.9873 - accuracy: 0.4974
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 41/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9849 - accuracy: 0.5053
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 42/1000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.9850 - accuracy: 0.5059
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 43/1000
# 17/17 [==============================] - 1s 71ms/step - loss: 0.9864 - accuracy: 0.5021
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 44/1000
# 17/17 [==============================] - 1s 86ms/step - loss: 0.9860 - accuracy: 0.5009
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 45/1000
# 17/17 [==============================] - 2s 87ms/step - loss: 0.9848 - accuracy: 0.4989
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 46/1000
# 17/17 [==============================] - 1s 67ms/step - loss: 0.9866 - accuracy: 0.4957
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 47/1000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.9876 - accuracy: 0.4955
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 48/1000
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9875 - accuracy: 0.4998
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 49/1000
# 17/17 [==============================] - 1s 67ms/step - loss: 0.9890 - accuracy: 0.4969
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 50/1000
# 17/17 [==============================] - 1s 74ms/step - loss: 0.9910 - accuracy: 0.4959
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 51/1000
# 17/17 [==============================] - 1s 56ms/step - loss: 0.9930 - accuracy: 0.4970
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 52/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9939 - accuracy: 0.4950
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 53/1000
# 17/17 [==============================] - 1s 52ms/step - loss: 0.9930 - accuracy: 0.4974
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 54/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9924 - accuracy: 0.4960
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 55/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9915 - accuracy: 0.4967
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 56/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9908 - accuracy: 0.4969
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 57/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9914 - accuracy: 0.4961
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 58/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9901 - accuracy: 0.4950
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 59/1000
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9906 - accuracy: 0.4925
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 60/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9900 - accuracy: 0.4979
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 61/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9880 - accuracy: 0.4997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 62/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9892 - accuracy: 0.5014
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 63/1000
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9869 - accuracy: 0.5029
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 64/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.9884 - accuracy: 0.5040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 65/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.9877 - accuracy: 0.4996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 66/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9891 - accuracy: 0.4992
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 67/1000
# 17/17 [==============================] - 1s 56ms/step - loss: 0.9909 - accuracy: 0.4977
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 68/1000
# 17/17 [==============================] - 1s 56ms/step - loss: 0.9902 - accuracy: 0.4983
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 69/1000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.9905 - accuracy: 0.5019
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 70/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.9875 - accuracy: 0.5015
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 71/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9972 - accuracy: 0.4993
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 72/1000
# 17/17 [==============================] - 1s 51ms/step - loss: 0.9989 - accuracy: 0.4913
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 73/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.9960 - accuracy: 0.4953
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 74/1000
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9935 - accuracy: 0.4981
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 75/1000
# 17/17 [==============================] - 1s 58ms/step - loss: 0.9906 - accuracy: 0.5001
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 76/1000
# 17/17 [==============================] - 1s 57ms/step - loss: 0.9900 - accuracy: 0.4983
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 77/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9904 - accuracy: 0.4986
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 78/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9903 - accuracy: 0.4963
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 79/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9909 - accuracy: 0.4990
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 80/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9906 - accuracy: 0.4938
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 81/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9894 - accuracy: 0.4951
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 82/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9914 - accuracy: 0.4921
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 83/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9875 - accuracy: 0.4997
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 84/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9883 - accuracy: 0.4987
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 85/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9860 - accuracy: 0.4983
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 86/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.9839 - accuracy: 0.4973
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 87/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9858 - accuracy: 0.5033
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 88/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9893 - accuracy: 0.4996
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 89/1000
# 17/17 [==============================] - 1s 45ms/step - loss: 0.9895 - accuracy: 0.5010
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 90/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9888 - accuracy: 0.5018
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 91/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9888 - accuracy: 0.5013
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 92/1000
# 17/17 [==============================] - 1s 60ms/step - loss: 0.9914 - accuracy: 0.4982
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 93/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9861 - accuracy: 0.5033
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 94/1000
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9861 - accuracy: 0.5039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 95/1000
# 17/17 [==============================] - 1s 53ms/step - loss: 0.9909 - accuracy: 0.4926
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 96/1000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.9919 - accuracy: 0.4950
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 97/1000
# 17/17 [==============================] - 1s 55ms/step - loss: 0.9916 - accuracy: 0.4986
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 98/1000
# 17/17 [==============================] - 1s 58ms/step - loss: 0.9911 - accuracy: 0.5004
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 99/1000
# 17/17 [==============================] - 1s 53ms/step - loss: 0.9922 - accuracy: 0.5024
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 100/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9880 - accuracy: 0.5027
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 101/1000
# 17/17 [==============================] - 1s 68ms/step - loss: 0.9875 - accuracy: 0.5030
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 102/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9861 - accuracy: 0.5023
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 103/1000
# 17/17 [==============================] - 1s 58ms/step - loss: 0.9866 - accuracy: 0.5049
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 104/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9877 - accuracy: 0.5097
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 105/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9889 - accuracy: 0.4989
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 106/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.9879 - accuracy: 0.4978
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 107/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9844 - accuracy: 0.5069
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 108/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9821 - accuracy: 0.5105
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 109/1000
# 17/17 [==============================] - 1s 46ms/step - loss: 0.9814 - accuracy: 0.5127
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 110/1000
# 17/17 [==============================] - 1s 52ms/step - loss: 0.9793 - accuracy: 0.5098
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 111/1000
# 17/17 [==============================] - 1s 51ms/step - loss: 0.9792 - accuracy: 0.5110
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 112/1000
# 17/17 [==============================] - 1s 50ms/step - loss: 0.9794 - accuracy: 0.5083
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 113/1000
# 17/17 [==============================] - 1s 53ms/step - loss: 0.9773 - accuracy: 0.5126
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 114/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9798 - accuracy: 0.5130
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 115/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9753 - accuracy: 0.5154
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 116/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9733 - accuracy: 0.5178
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 117/1000
# 17/17 [==============================] - 1s 52ms/step - loss: 0.9739 - accuracy: 0.5158
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 118/1000
# 17/17 [==============================] - 1s 49ms/step - loss: 0.9746 - accuracy: 0.5180
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 119/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.9780 - accuracy: 0.5104
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 120/1000
# 17/17 [==============================] - 1s 51ms/step - loss: 0.9761 - accuracy: 0.5142
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 121/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9753 - accuracy: 0.5195
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 122/1000
# 17/17 [==============================] - 1s 47ms/step - loss: 0.9758 - accuracy: 0.5159
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 123/1000
# 17/17 [==============================] - 1s 48ms/step - loss: 0.9728 - accuracy: 0.5194
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 124/1000
# 17/17 [==============================] - 1s 53ms/step - loss: 0.9748 - accuracy: 0.5161
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 125/1000
# 17/17 [==============================] - 1s 54ms/step - loss: 0.9736 - accuracy: 0.5198
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 126/1000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9700 - accuracy: 0.5176
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 127/1000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.9680 - accuracy: 0.5227
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 128/1000
# 17/17 [==============================] - 1s 51ms/step - loss: 0.9698 - accuracy: 0.5244
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 129/1000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.9684 - accuracy: 0.5207
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# ...
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 959/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9438 - accuracy: 0.5372
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 960/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9524 - accuracy: 0.5311
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 961/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9484 - accuracy: 0.5333
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 962/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9461 - accuracy: 0.5339
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 963/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9419 - accuracy: 0.5376
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 964/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9412 - accuracy: 0.5295
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 965/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9435 - accuracy: 0.5335
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 966/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9392 - accuracy: 0.5370
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 967/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9407 - accuracy: 0.5341
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 968/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9468 - accuracy: 0.5326
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 969/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9484 - accuracy: 0.5323
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 970/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9477 - accuracy: 0.5326
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 971/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9490 - accuracy: 0.5316
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 972/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9432 - accuracy: 0.5355
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 973/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9462 - accuracy: 0.5329
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 974/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9474 - accuracy: 0.5362
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 975/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9439 - accuracy: 0.5381
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 976/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9393 - accuracy: 0.5380
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 977/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9407 - accuracy: 0.5361
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 978/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9662 - accuracy: 0.5270
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 979/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9627 - accuracy: 0.5219
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 980/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9569 - accuracy: 0.5307
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 981/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9515 - accuracy: 0.5352
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 982/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9539 - accuracy: 0.5308
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 983/1000
# 17/17 [==============================] - 1s 44ms/step - loss: 0.9536 - accuracy: 0.5350
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 984/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9537 - accuracy: 0.5320
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 985/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9506 - accuracy: 0.5369
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 986/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9509 - accuracy: 0.5341
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 987/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9521 - accuracy: 0.5334
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 988/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9531 - accuracy: 0.5354
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 989/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9530 - accuracy: 0.5333
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 990/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9493 - accuracy: 0.5292
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 991/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9463 - accuracy: 0.5364
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 992/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9505 - accuracy: 0.5343
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 993/1000
# 17/17 [==============================] - 1s 43ms/step - loss: 0.9473 - accuracy: 0.5325
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 994/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9468 - accuracy: 0.5350
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 995/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9468 - accuracy: 0.5351
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 996/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9457 - accuracy: 0.5349
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 997/1000
# 17/17 [==============================] - 1s 41ms/step - loss: 0.9539 - accuracy: 0.5290
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 998/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9561 - accuracy: 0.5315
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 999/1000
# 17/17 [==============================] - 1s 40ms/step - loss: 0.9520 - accuracy: 0.5302
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 1000/1000
# 17/17 [==============================] - 1s 42ms/step - loss: 0.9494 - accuracy: 0.5376
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr

# %%
sample = next(iter(train_dataset))
x = np.arange(len(sample[0].numpy()))
y_pred = online_implementation(sample[0]).numpy().flatten()
y_true = sample[1].numpy().flatten()
sample_plot = 200
plt.scatter(x[:sample_plot], y_true[:sample_plot], label="True", alpha=0.5)
plt.scatter(x[:sample_plot], y_pred[:sample_plot], label="Predictions", marker="x")
plt.legend()
tf.keras.metrics.Recall(name="recall", thresholds=0)

# %%
# Plot history loss and RMSE for training and validation set; train solid line, validation dashed line
fig, (top_ax, bottom_ax) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

hist = local_implementation.history.history

top_ax.plot(hist['loss'], label='train_loss', c='b')
top_ax.plot(hist['val_loss'], label='val_loss', linestyle='--', c='b')
second_ax = top_ax.twinx()
# Plot precision and recall on second axis in orange and red respectively
second_ax.plot(hist['precision'], label='train_precision', c='orange')
second_ax.plot(hist['val_precision'], label='val_precision', linestyle='--', c='orange')
second_ax.plot(hist['recall'], label='train_recall', c='r')
second_ax.plot(hist['val_recall'], label='val_recall', linestyle='--', c='r')
top_ax.set_ylabel('loss')
second_ax.set_ylabel('Precision/Recall')
# Merge top ax legend entries
handles, labels = top_ax.get_legend_handles_labels()
handles2, labels2 = second_ax.get_legend_handles_labels()
top_ax.legend(handles + handles2, labels + labels2)


bottom_ax.plot(hist['lr'], label='lr', c='g')
bottom_ax.set_xlabel('Epoch')
bottom_ax.set_ylabel('Learning rate')

# New plot with auc and accuracy
fig, ax = plt.subplots()
ax.plot(hist['auc'], label='train_auc', c='orange')
ax.plot(hist['val_auc'], label='val_auc', linestyle='--', c='orange')
twinax = ax.twinx()
twinax.plot(hist['binary_accuracy'], label='train_accuracy', c='r')
twinax.plot(hist['val_binary_accuracy'], label='val_accuracy', linestyle='--', c='r')
ax.set_xlabel('Epoch')
ax.set_ylabel('AUC')
twinax.set_ylabel('Accuracy')
# Merge legend entries
handles, labels = ax.get_legend_handles_labels()
twinhandles, twinlabels = twinax.get_legend_handles_labels()
ax.legend(handles + twinhandles, labels + twinlabels)

# %%
# Evaluate model on test set
online_implementation.evaluate(test_dataset)
